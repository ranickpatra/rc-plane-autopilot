# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
delta_t = 0.01

# %%
columns = ['roll', 'pitch', 'yaw', 'rps', 'fin1', 'fin2', 'fin3', 'fin4']
data = []
with open('./data_1.txt', 'r') as f:
    data = [l.strip()[:-1] for l in f.readlines() if len(l.strip()) > 0]
data = [[float(_d) for _d in d.split(',')] for d in data]
data = np.array(data)
df_raw_data = pd.DataFrame(data=data, columns=columns)
df_raw_data
# Out:
#       roll  pitch    yaw   rps  fin1  fin2  fin3  fin4
# 0    -1.65  -1.60   1.20  0.01  30.0 -30.0  30.0 -30.0
# 1    -1.66  -1.60   1.20  0.01  30.0 -30.0  30.0 -30.0
# 2    -1.66  -1.60   1.19  0.01  30.0 -30.0  30.0 -30.0
# 3    -1.67  -1.60   1.19  0.01  30.0 -30.0  30.0 -30.0
# 4    -1.67  -1.61   1.18  0.01  30.0 -30.0  30.0 -30.0
# ...    ...    ...    ...   ...   ...   ...   ...   ...
# 1973 -2.31  -0.81  22.63  0.16 -30.0  30.0  30.0 -30.0
# 1974 -2.73  -0.75  23.89  0.12 -30.0  30.0  30.0 -30.0
# 1975 -2.87  -0.84  23.79  0.12  30.0  30.0  30.0 -30.0
# 1976 -3.10  -0.96  23.54  0.12  30.0 -30.0  30.0 -30.0
# 1977 -3.24  -1.07  23.25  0.12  30.0 -30.0  30.0 -30.0
#
# [1978 rows x 8 columns]

# %%
plt.figure(figsize=(20,20))

columns_to_plot = ['rps']
plt.subplot(6,1,1)
plt.plot(df_raw_data[columns_to_plot])
plt.legend(columns_to_plot)
plt.grid(which='both', linewidth=0.5)

columns_to_plot = ['roll', 'pitch', 'yaw']
plt.subplot(6,1,2)
plt.plot(df_raw_data[columns_to_plot])
plt.legend(columns_to_plot)
plt.grid(which='both', linewidth=0.5)




columns_to_plot = ['fin1']
plt.subplot(6,1,3)
plt.plot(df_raw_data[columns_to_plot], color='red')
plt.legend(columns_to_plot)
plt.grid(which='both', linewidth=0.5)

columns_to_plot = ['fin3']
plt.subplot(6,1,4)
plt.plot(df_raw_data[columns_to_plot], color='green')
plt.legend(columns_to_plot)
plt.grid(which='both', linewidth=0.5)

columns_to_plot = ['fin2']
plt.subplot(6,1,5)
plt.plot(df_raw_data[columns_to_plot], color='indigo')
plt.legend(columns_to_plot)
plt.grid(which='both', linewidth=0.5)

columns_to_plot = ['fin4']
plt.subplot(6,1,6)
plt.plot(df_raw_data[columns_to_plot], color='orange')
plt.legend(columns_to_plot)
plt.grid(which='both', linewidth=0.5)




# Adjust layout to prevent overlap
plt.tight_layout()
plt.show()
