# %% [markdown]
# # Test condition of data_3.txt
#
# Starting of drone
#
# then throttle up slowly
#
# goto max throttle
#
# then 1 electrical tape slips out from blade
#
# then stop

# %%
# %matplotlib inline
from IPython.display import Markdown, display
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
# loop time
LOOP_TIME = 10000 / 1e6
LOOP_TIME
# Out:
# 0.01

# %%
columns = ['roll', 'pitch', 'yaw', 'prop']
data = []
with open('./data_1.txt', 'r') as f:
    data = [l.strip()[:-1] for l in f.readlines() if len(l.strip()) > 0]
data = [[float(_d) for _d in d.split(',')] for d in data]
data = np.array(data)
df_raw = pd.DataFrame(data=data, columns=columns)
df_raw
# Out:
#        roll  pitch     yaw  prop
# 0     -5.22  -0.48    1.95  0.01
# 1     -5.22  -0.48    1.95  0.01
# 2     -5.22  -0.48    1.95  0.01
# 3     -5.22  -0.48    1.95  0.01
# 4     -5.22  -0.48    1.95  0.01
# ...     ...    ...     ...   ...
# 2122 -22.64  -1.52  137.89  0.01
# 2123 -22.72  -1.52  137.87  0.01
# 2124 -22.80  -1.53  137.85  0.01
# 2125 -22.88  -1.54  137.83  0.01
# 2126 -22.96  -1.54  137.81  0.01
#
# [2127 rows x 4 columns]

# %%
plt.figure(figsize=(20,7))
# plt.plot(df_raw['prop'][1300:1800])
plt.plot(df_raw['prop'])
plt.show()

# %%
# plot sections
def plot_sections(df, ranges):
    df = df[ranges[0]:ranges[1]]
    plt.figure(figsize=(20,7))
    plt.plot(df)
    plt.legend(df.columns)
    plt.show()
